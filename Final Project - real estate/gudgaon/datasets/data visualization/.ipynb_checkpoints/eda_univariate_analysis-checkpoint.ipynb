# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("gurgaon_properties_cleaned_v2.csv")

# %%
df.shape
# Out:
# (3841, 24)

# %%
df.head(2)
# Out:
#   property_type                 society      sector  price_cr  price_per_sqft  \
# 0          flat  experion the heartsong  sector 108      3.00         18392.0
# 1          flat            tulip violet   sector 69      1.37          8675.0
#
#      area                                       areaWithType  bedRoom  \
# 0  1631.0  Super Built up area 2779(258.18 sq.m.)Built Up...        4
# 1  1579.0  Super Built up area 1578(146.6 sq.m.)Carpet ar...        3
#
#    bathroom balcony  ...  built_up_area carpet_area study room  servant room  \
# 0         5      3+  ...        2204.25     1631.07          0             1
# 1         3       1  ...            NaN     1538.00          0             0
#
#    store room  pooja room  others  furnishing_type  luxury_score  \
# 0           0           0       0                1           149
# 1           0           1       0                0            95
#
#    nearbyLoc_score
# 0               58
# 1               61
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3841 entries, 0 to 3840
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_type        3841 non-null   object
#  1   society              3840 non-null   object
#  2   sector               3841 non-null   object
#  3   price_cr             3824 non-null   float64
#  4   price_per_sqft       3824 non-null   float64
#  5   area                 3824 non-null   float64
#  6   areaWithType         3841 non-null   object
#  7   bedRoom              3841 non-null   int64
#  8   bathroom             3841 non-null   int64
#  9   balcony              3841 non-null   object
#  10  floorNum             3821 non-null   float64
#  11  facing               2723 non-null   object
#  12  agePossession        3841 non-null   object
#  13  super_built_up_area  1915 non-null   float64
#  14  built_up_area        1766 non-null   float64
# ...

# %%
df.duplicated().sum()
# Out:
# 121

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (3720, 24)

# %%
df.isna().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price_cr                 16
# price_per_sqft           16
# area                     16
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                 20
# facing                 1061
# agePossession             0
# super_built_up_area    1844
# built_up_area          1995
# carpet_area            1833
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxury_score              0
# nearbyLoc_score           0
# dtype: int64

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# ## Property_types

# %%
ax=df.property_type.value_counts().plot(kind='bar')

# Annotate each bar with its count
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', fontsize=12, color='black', xytext=(0, 5), textcoords='offset points')

# Set labels and title
plt.xlabel('Property Type')
plt.ylabel('Count')
plt.title('Count of Each Property Type')

plt.show()

# %% [markdown]
# - No missing values
# - 25% are houses and 75% are flats

# %% [markdown]
# ## society

# %%
df.society.value_counts().shape
# Out:
# (682,)

# %%
df.society.describe()
# Out:
# count            3719
# unique            682
# top       independent
# freq              512
# Name: society, dtype: object

# %%
df.society.value_counts()
# Out:
# independent                                 512
# tulip violet                                 75
# ss the leaf                                  73
# dlf new town heights                         42
# shapoorji pallonji joyville gurugram         42
#                                            ...
# la lagune                                     1
# tashee capital gateway                        1
# the nav manesar apartment                     1
# central park resort belgravia residences      1
# sbr minda sec 1 imt manesar                   1
# Name: society, Length: 682, dtype: int64

# %%
# observe the society data excluding independent properties and then normalize that data
df[df['society'] != 'independent']['society'].value_counts(normalize=True).cumsum().head(75)
# Out:
# tulip violet                            0.023386
# ss the leaf                             0.046149
# dlf new town heights                    0.059245
# shapoorji pallonji joyville gurugram    0.072342
# signature global park                   0.083255
#                                           ...
# dlf the primus                          0.488307
# umang monsoon breeze                    0.492360
# indiabulls enigma                       0.496414
# the close north                         0.500468
# ireo the corridors                      0.504210
# Name: society, Length: 75, dtype: float64

# %%
society_counts = df['society'].value_counts()

# Frequency distribution for societies
frequency_bins = {
    "Very High (>100)": (society_counts > 100).sum(),
    "High (50-100)": ((society_counts >= 50) & (society_counts <= 100)).sum(),
    "Average (10-49)": ((society_counts >= 10) & (society_counts < 50)).sum(),
    "Low (2-9)": ((society_counts > 1) & (society_counts < 10)).sum(),
    "Very Low (1)": (society_counts == 1).sum()
}
frequency_bins
# there are 310 societies which have one one property
# Out:
# {'Very High (>100)': 1,
#  'High (50-100)': 2,
#  'Average (10-49)': 92,
#  'Low (2-9)': 277,
#  'Very Low (1)': 310}

# %%
# bar plot for top 10 societies excluding independent properties 
df[df['society'] != 'independent']['society'].value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
# check for null values
df['society'].isnull().sum()
# Out:
# 1

# %%
df[df['society'].isnull()]
# Out:
#      property_type society     sector  price_cr  price_per_sqft    area  \
# 2192          flat     NaN  sector 78       0.6          3692.0  1625.0
#
#                             areaWithType  bedRoom  bathroom balcony  ...  \
# 2192  Built Up area: 1625 (150.97 sq.m.)        2         2       0  ...
#
#       built_up_area carpet_area study room  servant room  store room  \
# 2192         1625.0         NaN          0             0           0
#
#       pooja room  others  furnishing_type  luxury_score  nearbyLoc_score
# 2192           0       0                0             0                0
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Observations
# - Around 13% properties comes under independent tag.
# - there are 682 societies
# - top 75 societies have 50% properties and remaining 50% properties are in those 607 societies :
# - Very High (>100): Only 1 society has more than 100 listings.
# - High (50-100): 2 societies have between 50 to 100 listings
# -
# Average (10-49): 92 societies fall in this range with 10 to 49 listings eac
# -
# Low (2-9): 273 societies have between 2 to 9 listg
# Very Low (1): A significant number, 308 societies, have only 1 l
# - 1 missing value.ng.

# %% [markdown]
# ## Sector

# %%
df.sector.isna().sum()
# Out:
# 0

# %%
df.sector.value_counts().shape
# Out:
# (107,)

# %%
# top 10 sectors
df.sector.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: >

# %%
df.sector.value_counts()
# total 107 sectors
# Out:
# sohna road    168
# sector 85     108
# sector 102    107
# sector 92     100
# sector 69      93
#              ...
# sector 27       3
# sector 37       3
# sector 73       3
# sector 32       2
# sector 42       1
# Name: sector, Length: 107, dtype: int64

# %%
sector_counts = df['sector'].value_counts()

# Frequency distribution for sectors
sector_frequency_bins = {
    "Very High (>100)": (sector_counts > 100).sum(),
    "High (50-100)": ((sector_counts >= 50) & (sector_counts <= 100)).sum(),
    "Average (10-49)": ((sector_counts >= 10) & (sector_counts < 50)).sum(),
    "Low (2-9)": ((sector_counts > 1) & (sector_counts < 10)).sum(),
    "Very Low (1)": (sector_counts == 1).sum()
}
sector_frequency_bins
# Out:
# {'Very High (>100)': 3,
#  'High (50-100)': 26,
#  'Average (10-49)': 61,
#  'Low (2-9)': 16,
#  'Very Low (1)': 1}

# %% [markdown]
# ### Observation
# - There are 107 unique sectors in dataset.
# - frequency distribution on sector is as follows:
#   - Very High (>100) : 3 sectors have more than 100 listings
#   - High (50 to 100):25 sectors have between 50 to 100 listings
#   - Average (10 to 49):A majority, 60 sectors, fall in this range with 10 to 49 listings each
#   - Low (2 to 9): 16 sectors have between 2 to 9 listing
#   - Very Low (1): Interestingly, there are no sectors with only 1 listing

# %% [markdown]
# ## Price_cr

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price_cr', 'price_per_sqft',
#        'area', 'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum',
#        'facing', 'agePossession', 'super_built_up_area', 'built_up_area',
#        'carpet_area', 'study room', 'servant room', 'store room', 'pooja room',
#        'others', 'furnishing_type', 'luxury_score', 'nearbyLoc_score'],
#       dtype='object')

# %%
# cehck for null values
df['price_cr'].isnull().sum()
# Out:
# 16

# %%
df['price_cr'].describe()
# Out:
# count    3704.000000
# mean        2.530300
# std         2.973059
# min         0.070000
# 25%         0.950000
# 50%         1.520000
# 75%         2.750000
# max        31.500000
# Name: price_cr, dtype: float64

# %%
sns.histplot(df['price_cr'],kde=True,bins=50)
# Out:
# <Axes: xlabel='price_cr', ylabel='Count'>

# %%
sns.boxplot(x=df['price_cr'],color='red',)
plt.grid()

# %% [markdown]
# #### Descriptive Statistics
#
# -  Count: There are 3704 non-missing price entrie.
# - Mean Price: The average price is approximate 2.5353 crore
# - Median Price: The median (or 50th percentile) price 1.521.52 cror
# - Standard Deviation: The prices have a standard deviation of 2.98, indicating variability in the price
# - Range: Prices range from a minimum of 0.07 crores to a maximum of 31.5 crores.
# - IQR: The interquartile range (difference between 75th and 25th percentile) is from 0.95 crores to 2.75 c
#
# #### Visualization
# - Distribution: The histogram indicates that most properties are priced in the lower range (below 5 crores), with a few properties going beyond
# 10 crores
# - Box Plot: The box plot showcases the spread of the data and potential outliers. Properties priced above approximately 10 crores might be -considered outliers as they lie beyond the upper whisker of the box plot.
# - Missing Values: There are 16 missing values in the price column. ice column.

# %%
# lets check skewness and kurtosis
skewness = df.price_cr.skew()
kurtosis = df.price_cr.kurt()
print(skewness,kurtosis)
# Out:
# 3.274617059032142 14.932685783602167

# %% [markdown]
# - Skewness: The price distribution has a skewness of approximately 3.28, indicating a positive skew. This means that the distribution tail is skewed to the right, which aligns with our observation from the histogram where most properties have prices on the lower end with a few high-priced properties.
# -
# Kurtosis: The kurtosis value is approximately 14.93. A kurtosis value greater than 3 indicates a distribution with heavier tails and more outliers compared to a normal distribution.

# %%
# quantile analysis
df.price_cr.quantile([0.01,0.05,0.25,0.50,0.75,0.95,0.99])
# Out:
# 0.01     0.250
# 0.05     0.370
# 0.25     0.950
# 0.50     1.520
# 0.75     2.750
# 0.95     8.500
# 0.99    15.097
# Name: price_cr, dtype: float64

# %% [markdown]
# Quantile Analysis:
# - 1% Quantile: Only 1% of properties are priced below 0.25 crores.
# - 5% Quantile: 5% of properties are priced below 0.37 crores.
# - 95% Quantile: 95% of properties are priced below 8.5 crores.
# - 99% Quantile: 99% of properties are priced below 15.097 crores, indicating that very few properties are priced above this value.
# ralue.

# %%
# identify potential outliers using IQR method 
Q1 = df.price_cr.describe()['25%']
Q3 = df.price_cr.describe()['75%']
IQR = Q3 - Q1

IQR
# Out:
# 1.8

# %%
lower_bound =  Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(lower_bound, upper_bound)
# Out:
# -1.7500000000000002 5.45

# %%
outliers = df[(df.price_cr < lower_bound) | (df.price_cr > upper_bound)]
outliers
# there are too may outliers and we can't remove them
# Out:
#      property_type                   society     sector  price_cr  \
# 5             flat           dlf the belaire  sector 54     10.00
# 10           house      adani brahma samsara  sector 60     18.02
# 15            flat          dlf beverly park  sector 25      8.00
# 16           house               independent  sector 28     11.75
# 30           house               independent  sector 41      9.00
# ...            ...                       ...        ...       ...
# 3823          flat      central park resorts  sector 48     15.00
# 3824         house  unitech uniworld resorts  sector 33      9.50
# 3825          flat             pioneer araya  sector 62      8.35
# 3829         house        emaar mgf marbella  sector 66     11.00
# 3830         house           eldeco mansionz  sector 48      6.00
#
#       price_per_sqft    area  \
# 5            24557.0  4072.0
# 10           28200.0  6390.0
# 15           15384.0  5200.0
# 16           41315.0  2844.0
# ...

# %%
outliers.price_cr.describe()
# Out:
# count    431.000000
# mean       9.205893
# std        4.047999
# min        5.460000
# 25%        6.450000
# 50%        8.000000
# 75%       10.555000
# max       31.500000
# Name: price_cr, dtype: float64

# %% [markdown]
# #### outlier Analysis(using IQR method):
#
# - there are 431 properties considered as an outliers.
# - These outliers have avg price of approx 9.20 CR.
# - The range of outliers range from 5.46 to 31.5 cr

# %%
# price binning 
bins = [0,1,2,3,5,10,20,50]

bin_lables = ["0-1", "1-2", "2-3", "3-5", "5-10", "10-20", "20-50"]

pd.cut(df.price_cr,bins = bins, labels = bin_lables,right=False).value_counts().sort_index().plot(kind='bar')
pd.cut(df.price_cr,bins = bins, labels = bin_lables,right=False).value_counts().sort_index()
# Out:
# 0-1      1021
# 1-2      1321
# 2-3       512
# 3-5       373
# 5-10      347
# 10-20     119
# 20-50      11
# Name: price_cr, dtype: int64

# %%
# ecdf plot 
ecdf = df.price_cr.value_counts(normalize=True).sort_index().cumsum()
plt.plot(ecdf.index,ecdf,marker = '.',linestyle='none')
plt.grid()

# %%
df.price_cr.value_counts(normalize=True).sort_index()
# Out:
# 0.07     0.00027
# 0.16     0.00027
# 0.17     0.00027
# 0.19     0.00027
# 0.20     0.00216
#           ...
# 24.00    0.00027
# 25.00    0.00027
# 26.00    0.00054
# 27.50    0.00027
# 31.50    0.00027
# Name: price_cr, Length: 474, dtype: float64

# %%
# Price data is right skewed and have large amount of outliers 
# We can apply LOG to reduce outliers for RIGHT SKEWED and to make graph more normalize
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.histplot(x=df['price_cr'], kde=True, bins=50, color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.histplot(x=np.log1p(df['price_cr']), kde=True, bins=50, color='lightgreen') 
# as value of price is smaller (less than 0) , hence using LOG1P which gives natural log of (1 + X)
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
(np.log1p(df.price_cr)).skew()
# Out:
# 1.0677129108441454

# %%
(np.log1p(df.price_cr)).kurt()
# Out:
# 0.946783390642377

# %%
plt.figure(figsize=(15, 6))

# Distribution plot without log transformation
plt.subplot(1, 2, 1)
sns.boxplot(x=df['price_cr'], color='skyblue')
plt.title('Distribution of Prices (Original)')
plt.xlabel('Price (in Crores)')
plt.ylabel('Frequency')

# Distribution plot with log transformation
plt.subplot(1, 2, 2)
sns.boxplot(x=np.log1p(df['price_cr']), color='lightgreen')
plt.title('Distribution of Prices (Log Transformed)')
plt.xlabel('Log(Price)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# # price_per_sqft

# %%
df.price_per_sqft
# Out:
# 0       18392.0
# 1        8675.0
# 2       13953.0
# 3        4856.0
# 4        5198.0
#          ...
# 3836     9444.0
# 3837     9169.0
# 3838     5859.0
# 3839     6666.0
# 3840     6194.0
# Name: price_per_sqft, Length: 3720, dtype: float64

# %%
df.price_per_sqft.isnull().sum()
# Out:
# 16

# %%
df.price_per_sqft.describe()
# Out:
# count      3704.000000
# mean      13954.850162
# std       23300.036429
# min           4.000000
# 25%        6812.750000
# 50%        9023.000000
# 75%       13889.000000
# max      600000.000000
# Name: price_per_sqft, dtype: float64

# %%
sns.histplot(df.price_per_sqft, kde = True, bins = 50)
# Out:
# <Axes: xlabel='price_per_sqft', ylabel='Count'>

# %% [markdown]
# Most properties have a price_per_sqft ranging between approximately ₹0 and ₹40,000. There is a significant concentration in the lower range, with a few properties having exceptionally high price_per_sqft.

# %%
sns.boxplot(x=df.price_per_sqft)
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# The box plot clearly shows several outliers, especially on the higher side. The interquartile range (IQR) is relatively compact, but there are many data points beyond the "whiskers" of the box plot, indicating potential outliers

# %% [markdown]
# #### Observation
# - 16 Null values
# - right skewed
# - Potential outliers

# %% [markdown]
# # BedRooom

# %%
df.bedRoom
# Out:
# 0       4
# 1       3
# 2       3
# 3       4
# 4       2
#        ..
# 3836    1
# 3837    3
# 3838    4
# 3839    2
# 3840    2
# Name: bedRoom, Length: 3720, dtype: int64

# %%
df.bedRoom.describe()
# Out:
# count    3720.000000
# mean        3.369086
# std         1.968032
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        36.000000
# Name: bedRoom, dtype: float64

# %%
df.bedRoom.isnull().sum()
# Out:
# 0

# %%
df.bedRoom.value_counts().sort_index()
# Out:
# 1      128
# 2      951
# 3     1507
# 4      670
# 5      213
# 6       78
# 7       28
# 8       31
# 9       41
# 10      20
# 11       1
# 12      28
# 13       4
# 14       1
# 16      12
# 18       2
# 19       2
# 20       1
# 21       1
# 36       1
# Name: bedRoom, dtype: int64

# %%
df.bedRoom.value_counts().sort_index().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['bedRoom'].value_counts(normalize=True).plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='bedRoom'>

# %% [markdown]
# # BathRoomm

# %%
df.bathroom
# Out:
# 0       5
# 1       3
# 2       3
# 3       3
# 4       2
#        ..
# 3836    1
# 3837    3
# 3838    5
# 3839    2
# 3840    2
# Name: bathroom, Length: 3720, dtype: int64

# %%
df.bathroom.isnull().sum()
# Out:
# 0

# %%
df.bathroom.describe()
# Out:
# count    3720.000000
# mean        3.428495
# std         2.016134
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        36.000000
# Name: bathroom, dtype: float64

# %%
df.bathroom.value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df.bathroom.value_counts().head().plot(kind = 'pie')
# Out:
# <Axes: ylabel='bathroom'>

# %% [markdown]
# # Balcony

# %%
df.balcony
# Out:
# 0       3+
# 1        1
# 2        3
# 3        3
# 4        0
#         ..
# 3836     2
# 3837     3
# 3838    3+
# 3839     3
# 3840     2
# Name: balcony, Length: 3720, dtype: object

# %%
df.balcony.describe()
# Out:
# count     3720
# unique       5
# top         3+
# freq      1178
# Name: balcony, dtype: object

# %%
df.balcony.isna().sum()
# Out:
# 0

# %%
df.balcony.value_counts()
# Out:
# 3+    1178
# 3     1078
# 2      902
# 1      378
# 0      184
# Name: balcony, dtype: int64

# %%
df.balcony.value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: >

# %%
df.balcony.value_counts().sort_index().plot(kind = 'pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='balcony'>

# %% [markdown]
# # floor num

# %%
df.iloc[:,10:].head()
# Out:
#    floorNum      facing   agePossession  super_built_up_area  built_up_area  \
# 0       2.0  South-West  Relatively New               2779.0        2204.25
# 1      12.0        East  Relatively New               1578.0            NaN
# 2       9.0       North  Relatively New               1950.0            NaN
# 3       4.0       North  Moderately Old               1956.0            NaN
# 4       0.0         NaN  Relatively New                  NaN         481.00
#
#    carpet_area  study room  servant room  store room  pooja room  others  \
# 0      1631.07           0             1           0           0       0
# 1      1538.00           0             0           0           1       0
# 2      1161.00           0             1           0           0       0
# 3          NaN           0             0           0           0       0
# 4          NaN           0             0           0           0       0
#
#    furnishing_type  luxury_score  nearbyLoc_score
# ...

# %%
df.floorNum.isna().sum()
# Out:
# 20

# %%
df.floorNum.describe()
# Out:
# count    3700.000000
# mean        6.748649
# std         6.006355
# min         0.000000
# 25%         2.000000
# 50%         5.000000
# 75%        10.000000
# max        51.000000
# Name: floorNum, dtype: float64

# %%
df.floorNum.value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.boxplot(x = df.floorNum)
# Out:
# <Axes: xlabel='floorNum'>

# %% [markdown]
# # observation
# - The majority of the properties lie between the ground floor 0 and the 25th floor.
# - Floors 1 to 4 are particularly common, with the 3rd floor being the most frequent.
# - There are a few properties located at higher floors, but their frequency is much lower.
# - The box plot reveals that the majority of the properties are concentrated around the lower floors. The interquartile range (IQR) lies between approximately the 2nd and 10th floors.
# - Data points beyond the "whiskers" of the box plot, especially on the higher side, indicate potential outliers.

# %% [markdown]
# # facing

# %%
df.facing
# Out:
# 0       South-West
# 1             East
# 2            North
# 3            North
# 4              NaN
#            ...
# 3836           NaN
# 3837         North
# 3838          West
# 3839    South-West
# 3840         North
# Name: facing, Length: 3720, dtype: object

# %%
df.facing.isna().sum()
# Out:
# 1061

# %%
df.facing.fillna('NA',inplace = True)

# %%
df.facing.isna().sum()
# Out:
# 0

# %%
df.facing.value_counts()
# Out:
# NA            1061
# North-East     631
# East           630
# North          394
# West           250
# South          232
# North-West     194
# South-East     174
# South-West     154
# Name: facing, dtype: int64

# %%
df.facing.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # agePossession

# %%
df.agePossession.isna().sum()
# Out:
# 0

# %%
df.agePossession.value_counts()
# Out:
# Relatively New        1653
# New Property           596
# Moderately Old         572
# Undefined              319
# Old Property           315
# Under Construction     265
# Name: agePossession, dtype: int64

# %%
df.agePossession.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # areas

# %%
# super built up area
df.super_built_up_area.isna().sum()
# Out:
# 1844

# %%
df.super_built_up_area.describe()
# Out:
# count     1876.000000
# mean      1923.702852
# std        765.376373
# min         89.000000
# 25%       1474.250000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
sns.histplot(df['super_built_up_area'], bins=50, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='super_built_up_area', ylabel='Count'>

# %%
sns.boxplot(x = df.super_built_up_area.dropna(), color='lightgreen')
# Out:
# <Axes: xlabel='super_built_up_area'>

# %% [markdown]
# #### observation
# - Most properties have a super built-up area ranging between approximately 1,000 sq.ft and 2,500 sq.ft.
# - There are a few properties with a significantly larger area, leading to a right-skewed distribution.
# - The interquartile range (IQR) lies between roughly 1,447 sq.ft and 2,215 sq.ft, indicating that the middle 50% of the properties fall within this range.
# - There are several data points beyond the upper "whisker" of the box plot, indicating potential outliers. These are properties with an unusually large super built-up area.

# %%
# build up area 
df.built_up_area.isna().sum()
# Out:
# 1995

# %%
df.built_up_area.describe()
# Out:
# count      1725.000000
# mean       2407.799959
# std       17770.857799
# min           2.000000
# 25%        1115.000000
# 50%        1660.000000
# 75%        2430.000000
# max      737147.000000
# Name: built_up_area, dtype: float64

# %%
sns.histplot(df['built_up_area'].dropna(), bins=50, color='skyblue', kde=False)
# Out:
# <Axes: xlabel='built_up_area', ylabel='Count'>

# %%
sns.boxplot(x = df['built_up_area'].dropna(), color='lightgreen')
# Out:
# <Axes: xlabel='built_up_area'>

# %% [markdown]
# ### observation
# - Most properties have a built-up area ranging roughly between 500 sq.ft and 3,500 sq.ft.
# - There are very few properties with a much larger built-up area, leading to a highly right-skewed distribution.
# - The box plot confirms the presence of significant outliers on the higher side. The data's interquartile range (IQR) is relatively compact, but the "whiskers" of the box plot are stretched due to the outliers.
# - The presence of extreme values, especially on the higher side, suggests that there may be outliers or data errors. This could also be due to some properties being exceptionally large, like a commercial complex or an entire building being listed.

# %%
# carpet area 
df.carpet_area.isna().sum()
# Out:
# 1833

# %%
df.carpet_area.describe()
# Out:
# count      1887.000000
# mean       2518.170576
# std       22709.454208
# min          15.000000
# 25%         832.480000
# 50%        1300.000000
# 75%        1787.500000
# max      607936.000000
# Name: carpet_area, dtype: float64

# %%
sns.histplot(df['carpet_area'].dropna(), bins=50, color='skyblue', kde=False)
# Out:
# <Axes: xlabel='carpet_area', ylabel='Count'>

# %%
sns.boxplot(x = df['carpet_area'].dropna(), color='lightgreen')
# Out:
# <Axes: xlabel='carpet_area'>

# %% [markdown]
# - same observation as built up area

# %%
df.iloc[:,16:]
# Out:
#       study room  servant room  store room  pooja room  others  \
# 0              0             1           0           0       0
# 1              0             0           0           1       0
# 2              0             1           0           0       0
# 3              0             0           0           0       0
# 4              0             0           0           0       0
# ...          ...           ...         ...         ...     ...
# 3836           0             0           0           0       0
# 3837           0             0           0           0       0
# 3838           0             1           0           0       0
# 3839           0             0           1           0       0
# 3840           1             0           0           0       0
#
#       furnishing_type  luxury_score  nearbyLoc_score
# 0                   1           149               58
# 1                   0            95               61
# ...

# %% [markdown]
# # additional rooms

# %%
plt.figure(figsize=(20,12))
# create a subplot of pie charts for each room type 
for idx, room in enumerate(['study room', 'servant room','store room','pooja room','others'],1):
    ax = plt.subplot(2,3,idx)
    df[room].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, ax=ax)
    plt.title(f'distribution of {room}')

plt.tight_layout()
plt.show()

# %% [markdown]
# # furnishing_type

# %%
df.furnishing_type.isna().sum()
# Out:
# 0

# %%
df.furnishing_type.value_counts()
# Out:
# 0    2444
# 2    1070
# 1     206
# Name: furnishing_type, dtype: int64

# %%
df.furnishing_type.value_counts().plot.pie(autopct='%0.2f%%')
# Out:
# <Axes: ylabel='furnishing_type'>

# %% [markdown]
# # luxury score

# %%
df.luxury_score.isna().sum()
# Out:
# 0

# %%
df.luxury_score.describe()
# Out:
# count    3720.000000
# mean       70.978495
# std        53.060813
# min         0.000000
# 25%        31.000000
# 50%        58.000000
# 75%       110.000000
# max       174.000000
# Name: luxury_score, dtype: float64

# %%
sns.histplot(df['luxury_score'], bins=50, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='luxury_score', ylabel='Count'>

# %%
sns.boxplot(x = df['luxury_score'], color='lightgreen')
# Out:
# <Axes: xlabel='luxury_score'>

# %% [markdown]
# The luxury score distribution has multiple peaks, suggesting a multi-modal distribution. There's a significant number of properties with lower luxury scores (around 0-50), and another peak is observed around the 110-130 range.
#
# The box plot reveals that the majority of the properties have luxury scores between approximately 30 and 110. The interquartile range (IQR) lies between these values.

# %% [markdown]
# # nearbyLoc_score

# %%
df.nearbyLoc_score.isna().sum()
# Out:
# 0

# %%
df.nearbyLoc_score.describe()
# Out:
# count    3720.000000
# mean       50.566129
# std        21.204264
# min         0.000000
# 25%        39.000000
# 50%        55.000000
# 75%        64.000000
# max        98.000000
# Name: nearbyLoc_score, dtype: float64

# %%
sns.histplot(df.nearbyLoc_score, bins = 50, kde = True)
# Out:
# <Axes: xlabel='nearbyLoc_score', ylabel='Count'>

# %%
df.head()
# Out:
#   property_type                  society      sector  price_cr  \
# 0          flat   experion the heartsong  sector 108      3.00
# 1          flat             tulip violet   sector 69      1.37
# 2          flat  shree vardhman victoria   sector 70      1.62
# 3          flat  sare green parc phase 3   sector 92      0.95
# 4          flat               mvn athens  sohna road      0.25
#
#    price_per_sqft    area                                       areaWithType  \
# 0         18392.0  1631.0  Super Built up area 2779(258.18 sq.m.)Built Up...
# 1          8675.0  1579.0  Super Built up area 1578(146.6 sq.m.)Carpet ar...
# 2         13953.0  1161.0  Super Built up area 1950(181.16 sq.m.)Carpet a...
# 3          4856.0  1956.0             Super Built up area 1956(181.72 sq.m.)
# 4          5198.0   481.0                   Built Up area: 481 (44.69 sq.m.)
#
#    bedRoom  bathroom balcony  ...  built_up_area carpet_area study room  \
# ...
