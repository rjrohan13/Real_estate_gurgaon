# %%
with open ('flats.html',encoding='utf-8') as f:
    html = f.read()

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
import time

# %%
soup = BeautifulSoup(html,'lxml')

# %%
containers = soup.find_all('div',{'class':'projectTuple__tupleDetails'})

# %%
for i in containers:
    
    print(i.find('h2').text.strip())
    print(i.find('a',{"class":'projectTuple__projectName'}).text.strip())
    try:
        print(i.find('td',{"class":'srpTuple__col title_semiBold '}).text.strip())
    except:
        print('error')
# Out:
# 2, 3, 4 BHK Flat in Wagholi, Pune
# VTP Flamante
# error
# 1, 2, 3, 4 BHK Flat in Pimpri, Pune
# Renuka Gulmohar Phase 2
# error
# 2, 3 BHK Flat in Keshav Nagar, Pune
# K City
# error
# 2, 3 BHK Flat in Wakad, Pune
# My Home Wakad
# error
# 1, 2 BHK Flat in Phursungi, Pune
# The Mpire
# error
# 3 BHK Flat in Dhankawadi, Pune
# Pioneer Vasantshree
# error
# 2, 3, 4 BHK Flat in Chinchwad, Pune
# Runwal The Central Park
# error
# 2, 3 BHK Flat in Kharadi, Pune
# ARV Uthville
# error
# 2, 3 BHK Flat in Balewadi, Pune
# Naiknavare Avon Vista
# error
# 2, 3 BHK Flat in Wakad, Pune
# Kohinoor Courtyard One
# error
# 2, 3 BHK Flat in Moshi, Pune
# Shree Saai Fortune
# error
# 1, 2, 3 BHK Flat in Wakad, Pune
# Sukhwani Skylines
# error
# 2, 3, 4 BHK Flat in Baner, Pune
# Rahul Arcus
# error
# 4, 5, 6 BHK Flat in Baner, Pune
# Kasturi The Balmoral Hillside
# error
# 2, 3 BHK Flat in Baner, Pune
# Regency Astra
# error
# 1, 2 BHK Flat in Punawale, Pune
# Aishwaryam Insignia
# error
# 2, 3 BHK Flat in Phase 3 Hinjewadi , Pune
# Kasturi Eon Homes
# error
# 2, 3 BHK Flat in Kiwale, Pune
# K Town
# error
# 2 BHK Flat in Pisoli, Pune
# Yash Sherlyn Avenue
# error
# 1, 2, 3 BHK Flat in Keshav Nagar, Pune
# Shree Nivasa Elevia
# error
# 2, 3 BHK Flat in Tathawade, Pune
# Rama Metro Life Maxima Residences
# error
# 1, 2, 3 BHK Flat in Keshav Nagar, Pune
# Unique Legacy
# error
# 2, 3, 4 BHK Flat in Baner, Pune
# Tej Elevia
# error
# 2, 3 BHK Flat in Mohamadwadi, Pune
# Raheja Sterling
# error
# 2, 3 BHK Flat in Rahatani, Pune
# Legacy Kairos
# error

# %%
search_div  = soup.select_one('div[data-label="SEARCH"]')

# %%
s = search_div.select('section[data-hydration-on-demand="true"]')[0]

# %%
try:
    property_name = s.select_one('a.srpTuple__propertyName').text.strip()
    # Extract link
    # link = s.select_one('a.srpTuple__propertyName')['href']
    # society = s.select_one('#srp_tuple_society_heading').text.strip()
except:
    print('wrong')
# Out:
# wrong

# %%
property_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 property_name
#
# NameError: name 'property_name' is not defined

# %%
search_div  = soup.select_one('div[data-label="SEARCH"]')
csv_file = "C:/Users/ROHAN/Desktop/Data Science/campusx/Final Project - real estate/web Scrapping/flats_pune_data-samplecsv"


for soup in search_div.select('section[data-hydration-on-demand="true"]'):
# extract property name and property sub-name 
    i = 1
    try:
        property_name = soup.select_one('a.srpTuple__propertyName').text.strip()
        # Extract link
        link = soup.select_one('a.srpTuple__propertyName')['href']
        society = soup.select_one('#srp_tuple_society_heading').text.strip()
    except:
        continue
    # Detail Page
    page = requests.get(link, headers=headers)
    dpageSoup = BeautifulSoup(page.content, 'html.parser')
    req += 1
    try:
        #price Range
        price = dpageSoup.select_one('#pdPrice2').text.strip()
    except:
        price = ''

    # Area
    try:
        area = soup.select_one('#srp_tuple_price_per_unit_area').text.strip()
    except:
        area =''
    # Area with Type
    try:
        areaWithType = dpageSoup.select_one('#factArea').text.strip()
    except:
        areaWithType = ''


    # Configuration
    try:
        bedRoom = dpageSoup.select_one('#bedRoomNum').text.strip()
    except:
        bedRoom = ''
    try:
        bathroom = dpageSoup.select_one('#bathroomNum').text.strip()
    except:
        bathroom = ''
    try:
        balcony = dpageSoup.select_one('#balconyNum').text.strip()
    except:
        balcony = ''

    try:
        additionalRoom = dpageSoup.select_one('#additionalRooms').text.strip()
    except:
        additionalRoom = ''


    # Address

    try:
        address = dpageSoup.select_one('#address').text.strip()
    except:
        address = ''
    # Floor Number
    try:
        floorNum = dpageSoup.select_one('#floorNumLabel').text.strip()
    except:
        floorNum = ''

    try:
        facing = dpageSoup.select_one('#facingLabel').text.strip()
    except:
        facing = ''

    try:
        agePossession = dpageSoup.select_one('#agePossessionLbl').text.strip()
    except:
        agePossession = ''

    # Nearby Locations

    try:
        nearbyLocations = [i.text.strip() for i in dpageSoup.select_one('div.NearByLocation__tagWrap').select('span.NearByLocation__infoText')]
    except:
        nearbyLocations = ''

    # Descriptions
    try:
        description = dpageSoup.select_one('#description').text.strip()
    except:
        description = ''

    # Furnish Details
    try:
        furnishDetails = [i.text.strip() for i in dpageSoup.select_one('#FurnishDetails').select('li')]
    except:
        furnishDetails = ''

    # Features
    if furnishDetails:
        try:
            features = [i.text.strip() for i in dpageSoup.select('#features')[1].select('li')]
        except:
            features = ''
    else:
        try:
            features = [i.text.strip() for i in dpageSoup.select('#features')[0].select('li')]
        except:
            features = ''



    # Rating by Features
    try:
        rating = [i.text for i in dpageSoup.select_one('div.review__rightSide>div>ul>li>div').select('div.ratingByFeature__circleWrap')]
    except:
        rating = ''
    # print(top_f)

    try:
        # Property ID
        property_id = dpageSoup.select_one('#Prop_Id').text.strip()
    except:
        property_id = ''

    # Create a dictionary with the given variables
    property_data = {
    'property_name': property_name,
    'link': link,
    'society': society,
    'price': price,
    'area': area,
    'areaWithType': areaWithType,
    'bedRoom': bedRoom,
    'bathroom': bathroom,
    'balcony': balcony,
    'additionalRoom': additionalRoom,
    'address': address,
    'floorNum': floorNum,
    'facing': facing,
    'agePossession': agePossession,
    'nearbyLocations': nearbyLocations,
    'description': description,
    'furnishDetails': furnishDetails,
    'features': features,
    'rating': rating,
    'property_id': property_id
}

    
    temp_df = pd.DataFrame.from_records([property_data])
    # print(temp_df)
    flats = pd.concat([flats, temp_df], ignore_index=True)
    i += 1
    print(i)
    if os.path.isfile(csv_file):
    # Append DataFrame to the existing file without header
        temp_df.to_csv(csv_file, mode='a', header=False, index=False)
    else:
        # Write DataFrame to the file with header
        temp_df.to_csv(csv_file, mode='a', header=True, index=False)

    if req % 4==0:
        time.sleep(10)
    if req % 15 == 0:
        time.sleep(50)

# %%
temp_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 temp_df
#
# NameError: name 'temp_df' is not defined
